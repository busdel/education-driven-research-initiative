# %%
# --- 1. BÖLÜM: DEĞİŞKENLER VE LİSTELER ---

hasta_adi = "Patient_1"
yas = 45
seker_degeri = 110.5  #(float)
teshis_kondu_mu = False  # (boolean)

# Listeler (Birden fazla veriyi tek bir yapıda tutuyoruz)
seker_test_sonuclari = [95, 120, 145, 88, 110]

# Bilgileri ekrana yazdıralım
print("Hasta Adı:", hasta_adi)
print("Yaş:", yas)
print("Tüm Test Sonuçları:", seker_test_sonuclari)

print("İlk Hastanın Sonucu:", seker_test_sonuclari[0])

# %%
# --- 2. BÖLÜM: SÖZLÜKLER (DICTIONARIES) ---

# Bir hastanın tüm tıbbi geçmişini tek bir değişkende toplayalım
hasta_dosyasi = {
    "tc_no": "xxxxxxx",
    "ad_soyad": "Patient_1",
    "yas": 30,
    "kan_grubu": "B Rh+",
    "diyabet_durumu": False,
    "son_bes_olcum": [110, 125, 130, 115, 140] # Sözlük içinde liste bile tutabiliriz!
}

# Veriye erişmek: Sadece anahtar ismini yazıyoruz
print(f"Sistemdeki Hasta: {hasta_dosyasi['ad_soyad']}")
print(f"Hastanın Yaşı: {hasta_dosyasi['yas']}")

# Sözlükteki bir veriyi güncelleyelim (Doğum günü gelmiş olsun)
hasta_dosyasi["yas"] = 25

# Yeni bir bilgi ekleyelim (Boy bilgisi sisteme giriliyor)
hasta_dosyasi["boy"] = 170

print("--- Güncel Hasta Kartı ---")
print(hasta_dosyasi)

# %%
# --- 3. BÖLÜM: DÖNGÜLER (LOOPS) ---

olcumler = [110, 125, 130, 115, 140, 85, 98]

print("--- Günlük Şeker Analiz Raporu ---")

# 'for' döngüsü listenin içindeki her bir elemanı 'deger' ismine atar ve sırayla çalıştırır.
for deger in olcumler:
    if deger >= 126:
        # Şeker 126 ve üzeriyse riskli kabul edilir (Örnek mantık)
        status = "YÜKSEK (Risk Grubu)"
    elif deger < 90:
        status = "DÜŞÜK (Kontrol Gerekli)"
    else:
        status = "NORMAL (Sağlıklı)"

    # Her bir ölçüm için sonucu ekrana yazdıralım
    print(f"Ölçüm Değeri: {deger} -> Durum: {status}")

print("--- Analiz Başarıyla Tamamlandı ---")
# Out:
# --- Günlük Şeker Analiz Raporu ---
# Ölçüm Değeri: 110 -> Durum: NORMAL (Sağlıklı)
# Ölçüm Değeri: 125 -> Durum: NORMAL (Sağlıklı)
# Ölçüm Değeri: 130 -> Durum: YÜKSEK (Risk Grubu)
# Ölçüm Değeri: 115 -> Durum: NORMAL (Sağlıklı)
# Ölçüm Değeri: 140 -> Durum: YÜKSEK (Risk Grubu)
# Ölçüm Değeri: 85 -> Durum: DÜŞÜK (Kontrol Gerekli)
# Ölçüm Değeri: 98 -> Durum: NORMAL (Sağlıklı)
# --- Analiz Başarıyla Tamamlandı ---

# %%
# --- 4. BÖLÜM: FONKSİYONLAR (FUNCTIONS) ---

def analyze_glucose(name, sample_list):
    results = []

    for i in sample_list:
        if i >= 126:
            results.append(f"{name} has high blood sugar which is {i}")
        elif i < 90:
            results.append(f"{name} has low blood sugar which is {i}")
        else:
            results.append(f"{name} has normal blood sugar which is {i}")

    return results


result = analyze_glucose("Patient_1", [140, 200, 35, 60])
print(result)

# %%
#5. Bölüm Pandas ile Pratik

import pandas as pd

# 1. DOSYA YÜKLEME (CSV URL üzerinden)
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

print(df)

print("--- İlk 5 Satır ---")
df.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2. VERİ YAPISINI İNCELEME
print("\n--- Veri Seti Özeti (Sütunlar ve Tipleri) ---")
df.info()
# Out:
# --- Veri Seti Özeti (Sütunlar ve Tipleri) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      920 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
# 3. MISSING VALUE (Eksik Veri) KONTROLÜ
print("\n--- Eksik Veri Sayıları ---")
# Hangi sütunda kaç tane NaN (boş hücre) var?
print(df.isnull().sum())
# Out:
# --- Eksik Veri Sayıları ---
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 4. TEMEL İSTATİSTİKLER (Mean, Min, Max)
print("\n--- Sayısal Verilerin Özeti ---")
# Bu komut yaş, bilet fiyatı (Fare) gibi sütunların ortalamasını, min/max değerlerini verir
df.describe()
# Out:
# --- Sayısal Verilerin Özeti ---
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Sadece bilet fiyatlarının istatistiksel dağılımı
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# 5. TABLO MANTIĞI: FİLTRELEME
# Sadece 1. sınıfta (Pclass=1) seyahat edenlerin yaş ortalamasına bakalım
birinci_sinif_yas = df[df['Pclass'] == 1]['Age'].mean()
print(f"\n1. Sınıf Yolcuların Yaş Ortalaması: {birinci_sinif_yas:.2f}")
# Out:
# 1. Sınıf Yolcuların Yaş Ortalaması: 38.23

# %%
# 5. TABLO MANTIĞI
#Age eksiklerini medyan ile dolduralım
df['Age'].dropna(df['Age'].median(), inplace=True)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 5. TABLO MANTIĞI
# Survived için Sex ve Pclass ile pivot tablosu
pivot_tablosu = df.pivot_table(index = "Sex", columns ="Pclass", values= "Survived", aggfunc="mean" )
display(pivot_tablosu)
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
# 5. TABLO MANTIĞI: GRUPLAMA (Insights)
# "Kadınlar ve çocuklar önce" kuralı işe yaramış mı?
print("\n--- Cinsiyete Göre Hayatta Kalma Oranı ---")
survival_by_sex = df.groupby('Sex')['Survived'].mean()
print(survival_by_sex)
# Out:
# --- Cinsiyete Göre Hayatta Kalma Oranı ---
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# HİSTOGRAM for titanic data
import matplotlib.pyplot as plt

# Tuvali/Sayfayı hazırla
plt.figure(figsize=(10, 6))


# bins: Kaç çubuk olacağı
# color: Çubuk rengi
# edgecolor: Çubukların kenar çizgisi (Yoksa birbirlerine yapışık görünüyor)
plt.hist(df['Age'], bins=10, color='blue', edgecolor='black')

# Başlık ve Eksen İsimleri
plt.title('Titanikteki Yaş Dağılımı')
plt.xlabel('Yaş')
plt.ylabel('Kişi Sayısı')

plt.savefig("pltdeneme2")
plt.show()

# %%
# BOXPLOT for titanic data

import matplotlib.pyplot as plt

# 1. Veriyi gruplara ayıralım (Matplotlib için bu şarttır)
hayatta_kalanlar = df[df['Survived'] == 1]['Fare'].dropna()
hayatını_kaybedenler = df[df['Survived'] == 0]['Fare'].dropna()

# 2. Verileri bir liste içinde toplayalım
data_to_plot = [hayatını_kaybedenler, hayatta_kalanlar]

# 3. Grafik sayfasını oluşturalım
plt.figure(figsize=(10, 6))

# 4. Boxplot'u çizelim (Matplotlib'in ana fonksiyonu)
# patch_artist=True: Kutuların içini renklendirmemizi sağlar
plt.boxplot(data_to_plot, patch_artist=True, tick_labels=['Ölenler', 'Kurtulanlar'])

# 5. Başlık ve etiketleri ekleyelim
plt.title('Hayatta Kalma Durumuna Göre Bilet Ücreti Dağılımı (Matplotlib)')
plt.ylabel('Bilet Ücreti (Fare)')
plt.xlabel('Durum')

# 6. Izgara (grid) ekleyelim ki değerler daha rahat okunsun
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# 6.Bölüm : Tabular veriyi inceleme (Heart diease veri seti ile)

# Veriyi yükleme
import pandas as pd
df = pd.read_csv("heart_disease_uci.csv")

# %%
# Satır ve Sütun Sayısı
df.shape
# Out:
# (920, 16)

# %%
# Sütun Tipleri
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
# Eksik Değerler 
print(df.isnull().sum())
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
# Temel İstatistikler
df.describe() # sadece sayısal sütunların istatistiklerini verir
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
# 0 = Sağlıklı, 1-4 = Hasta
print("Hastalık Durumu Dağılımı:")
print(df['num'].value_counts())

# Yüzdesel olarak görelim
print("\nOransal Dağılım (%):")
print(df['num'].value_counts(normalize=True) * 100)# normalize  0 ile 1 arasına sıkıştırıyor değerleri
# Out:
# Hastalık Durumu Dağılımı:
# num
# 0    411
# 1    265
# 2    109
# 3    107
# 4     28
# Name: count, dtype: int64
#
# Oransal Dağılım (%):
# num
# 0    44.673913
# 1    28.804348
# 2    11.847826
# 3    11.630435
# 4     3.043478
# Name: proportion, dtype: float64

# %%
# Cinsiyete (sex) göre, her hastalık seviyesindeki (num) ortalama yaşları (age) görelim
pivot_ornek = df.pivot_table(index='sex', columns='num', values='age', aggfunc='mean')

print(pivot_ornek)
# Out:
# num             0          1          2          3          4
# sex
# Female  51.187500  55.333333  53.800000  60.375000  64.000000
# Male    50.202247  53.297872  57.959596  59.121212  58.846154

# %%
# Cinsiyete göre yaş ve kolesterol ortalamaları
print("Cinsiyet Bazlı Ortalamalar:")
display(df.groupby('sex')[['age', 'chol', 'thalch']].mean())
# Out:
# Cinsiyet Bazlı Ortalamalar:
#               age        chol      thalch
# sex
# Female  52.474227  241.481283  146.244792
# Male    53.787879  187.864865  135.063893

# %%
# yaşı 50'nin üstü ve kolestrolü 240'tan büyük kaç kişi var bulalım
riskli_grup = df[(df['age'] > 50) & (df['chol'] > 240)]
print(f"Yüksek Riskli Hasta Sayısı: {len(riskli_grup)}")
# Out:
# Yüksek Riskli Hasta Sayısı: 231

# %%
# Kolestrol sütunundaki 0 değerlerini mean value ile dolduralım çünkü 0 diye bir kolestrol ölçüm verisi olamaz

import numpy as np

# 1. Adım: 0 değerlerini NaN (boş) yapalım
df['chol'] = df['chol'].replace(0, np.nan)

# 2. Adım: Tüm sütunun ortalamasını hesaplayalım
genel_ortalama = df['chol'].mean()
print(f"Hesaplanan Genel Ortalama: {genel_ortalama:.2f}")

# 3. Adım: Boş yerleri bu ortalama ile dolduralım
df['chol'] = df['chol'].fillna(genel_ortalama)

# Kontrol:
print(f"Kalan boş değer sayısı: {df['chol'].isnull().sum()}")
# Out:
# Hesaplanan Genel Ortalama: 246.83
# Kalan boş değer sayısı: 0

# %%
# 7.BÖLÜM: Veri görselleştirme ( HİSTOGRAM)

import matplotlib.pyplot as plt  
import seaborn as sns            

# Grafiğin boyutunu belirleyelim (Genişlik=10, Yükseklik=6 birim)
plt.figure(figsize=(10, 6)) 

# Grafiği çizdiren ana fonksiyon
sns.histplot(df['age'], bins=10, kde=True, color='red') 

# Başlık ve Eksen İsimleri
plt.title('Hastalarda Yaş Dağılımı') 
plt.xlabel('Yaş') 
plt.ylabel('Kişi Sayısı') 

# Grafiği ekrana bas
plt.show()

"""Bu histogram, veri setimizdeki yaş dağılımını gösterir. 
Gözlemlerimize göre veriler orta ve ileri yaş grubunda yoğunlaşmaktadır. 
Medikal araştırmalarda bu, kalp hastalığı risk faktörlerinin daha çok 
hangi yaş döneminde klinik olarak takip edildiğini anlamamıza yardımcı olur."""
# Out:
# 'Bu histogram, veri setimizdeki yaş dağılımını gösterir. \nGözlemlerimize göre veriler orta ve ileri yaş grubunda yoğunlaşmaktadır. \nMedikal araştırmalarda bu, kalp hastalığı risk faktörlerinin daha çok \nhangi yaş döneminde klinik olarak takip edildiğini anlamamıza yardımcı olur.'

# %%
# BOX PLOT

# Yeni bir grafik sayfası açıyoruz
plt.figure(figsize=(10, 6))


# x: Kategorik veri (Hastalık durumu 0,1,2,3,4)
# y: Sayısal veri (Maksimum Kalp Hızı)
sns.boxplot(x='num', y='thalch', data=df, palette='colorblind')

# axis isimleri
plt.title('Hastalık Seviyesine Göre Maksimum Kalp Hızı Dağılımı')
plt.xlabel('Hastalık Seviyesi (0=Sağlıklı, 1-4=Hasta)')
plt.ylabel('Maksimum Kalp Hızı (thalch)')


plt.show()
""" Boxplot grafiği, kalp hastalığı şiddeti arttıkça (0'dan 4'e doğru) ulaşılan maksimum 
kalp hızının düşme eğiliminde olduğunu göstermektedir.Medikal araştırmalarda bu grafik
bir değişkenin hastalık teşhisinde ne kadar ayırt edici olduğunu saptamak için hayati öneme sahiptir."""
# Out:
# /var/folders/vs/40yjc6mn0tg755qw3g2s03_c0000gn/T/ipykernel_67184/3622158808.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='num', y='thalch', data=df, palette='colorblind')
# " Boxplot grafiği, kalp hastalığı şiddeti arttıkça (0'dan 4'e doğru) ulaşılan maksimum \nkalp hızının düşme eğiliminde olduğunu göstermektedir.Medikal araştırmalarda bu grafik\nbir değişkenin hastalık teşhisinde ne kadar ayırt edici olduğunu saptamak için hayati öneme sahiptir."

# %%
# SCATTER PLOT

# Boyut ayarı
plt.figure(figsize=(10, 6))

renkler = ["blue","red","green","yellow","purple"]# renkleri belirlemek için list oluşturdum
# x: Yaş, y: Kolesterol, hue: Renklendirme (Hastalık var mı yok mu?)
sns.scatterplot(x='age', y='chol', data=df, color = "blue", alpha=1)# alpha şeffaflığı belirler

# axis isimleri
plt.title('Yaş ve Kolesterol Arasındaki İlişki')
plt.xlabel('Yaş')
plt.ylabel('Kolesterol (mg/dl)')
#plt.legend(title='Hastalık Seviyesi') # Sağdaki renk tablosu

# Göster
plt.show()

"""Scatter plot, yaş ve kolesterol gibi iki sayısal değişken arasındaki korelasyonu incelememizi sağlar. 
Renklendirme (hue) sayesinde, belirli yaş ve kolesterol aralıklarında hastalık yoğunluğunun nasıl değiştiğini görebiliriz.
Medikal araştırmalarda bu, risk altındaki popülasyonu görsel olarak kümelemek (clustering) için kullanılır."""
# Out:
# 'Scatter plot, yaş ve kolesterol gibi iki sayısal değişken arasındaki korelasyonu incelememizi sağlar. \nRenklendirme (hue) sayesinde, belirli yaş ve kolesterol aralıklarında hastalık yoğunluğunun nasıl değiştiğini görebiliriz.\nMedikal araştırmalarda bu, risk altındaki popülasyonu görsel olarak kümelemek (clustering) için kullanılır.'

# %%
import matplotlib.pyplot as plt
sns.set_theme(style = 'ticks')
sns.pairplot(df, hue= "num")
