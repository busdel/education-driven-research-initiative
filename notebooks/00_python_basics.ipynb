# %%
# --- 1. BÖLÜM: DEĞİŞKENLER VE LİSTELER ---

hasta_adi = "Onur Leblebici"
yas = 45
seker_degeri = 110.5  #(float)
teshis_kondu_mu = False  # (boolean)

# Listeler (Birden fazla veriyi tek bir yapıda tutuyoruz)
seker_test_sonuclari = [95, 120, 145, 88, 110]

# Bilgileri ekrana yazdıralım
print("Hasta Adı:", hasta_adi)
print("Yaş:", yas)
print("Tüm Test Sonuçları:", seker_test_sonuclari)

print("İlk Hastanın Sonucu:", seker_test_sonuclari[0])
# Out:
# Hasta Adı: Onur Leblebici
# Yaş: 45
# Tüm Test Sonuçları: [95, 120, 145, 88, 110]
# İlk Hastanın Sonucu: 95

# %%
# --- 2. BÖLÜM: SÖZLÜKLER (DICTIONARIES) ---

# Bir hastanın tüm tıbbi geçmişini tek bir değişkende toplayalım
hasta_dosyasi = {
    "tc_no": "12345678901",
    "ad_soyad": "Onuralp Leblebicier",
    "yas": 19,
    "kan_grubu": "B Rh+",
    "diyabet_durumu": False,
    "son_bes_olcum": [110, 125, 130, 115, 140] # Sözlük içinde liste bile tutabiliriz!
}

# Veriye erişmek: Sadece anahtar ismini yazıyoruz
print(f"Sistemdeki Hasta: {hasta_dosyasi['ad_soyad']}")
print(f"Hastanın Yaşı: {hasta_dosyasi['yas']}")

# Sözlükteki bir veriyi güncelleyelim (Doğum günü gelmiş olsun)
hasta_dosyasi["yas"] = 20

# Yeni bir bilgi ekleyelim (Boy bilgisi sisteme giriliyor)
hasta_dosyasi["boy"] = 185

print("--- Güncel Hasta Kartı ---")
print(hasta_dosyasi)
# Out:
# Sistemdeki Hasta: Onuralp Leblebicier
# Hastanın Yaşı: 19
# --- Güncel Hasta Kartı ---
# {'tc_no': '12345678901', 'ad_soyad': 'Onuralp Leblebicier', 'yas': 20, 'kan_grubu': 'B Rh+', 'diyabet_durumu': False, 'son_bes_olcum': [110, 125, 130, 115, 140], 'boy': 185}

# %%
# --- 3. BÖLÜM: DÖNGÜLER (LOOPS) ---

olcumler = [110, 125, 130, 115, 140, 85, 98]

print("--- Günlük Şeker Analiz Raporu ---")

# 'for' döngüsü listenin içindeki her bir elemanı 'deger' ismine atar ve sırayla çalıştırır.
for deger in olcumler:
    if deger >= 126:
        # Şeker 126 ve üzeriyse riskli kabul edilir (Örnek mantık)
        status = "YÜKSEK (Risk Grubu)"
    elif deger < 90:
        status = "DÜŞÜK (Kontrol Gerekli)"
    else:
        status = "NORMAL (Sağlıklı)"

    # Her bir ölçüm için sonucu ekrana yazdıralım
    print(f"Ölçüm Değeri: {deger} -> Durum: {status}")

print("--- Analiz Başarıyla Tamamlandı ---")
# Out:
# --- Günlük Şeker Analiz Raporu ---
# Ölçüm Değeri: 110 -> Durum: NORMAL (Sağlıklı)
# Ölçüm Değeri: 125 -> Durum: NORMAL (Sağlıklı)
# Ölçüm Değeri: 130 -> Durum: YÜKSEK (Risk Grubu)
# Ölçüm Değeri: 115 -> Durum: NORMAL (Sağlıklı)
# Ölçüm Değeri: 140 -> Durum: YÜKSEK (Risk Grubu)
# Ölçüm Değeri: 85 -> Durum: DÜŞÜK (Kontrol Gerekli)
# Ölçüm Değeri: 98 -> Durum: NORMAL (Sağlıklı)
# --- Analiz Başarıyla Tamamlandı ---

# %%
# --- 4. BÖLÜM: FONKSİYONLAR (FUNCTIONS) ---

def analyze_maker(name, sample_list):

    for i in sample_list:
        if i >= 100:
            print(f"{name} has high blood sugar which is {i}")
        elif i <= 50:
            print(f"{name} has low blood sugar which is {i}")
        else:
            print(f"{name} has normal blood sugar which is {i}")

analyze_maker("Onuralp", [140,200,35,60])
# Out:
# Onuralp has high blood sugar which is 140
# Onuralp has high blood sugar which is 200
# Onuralp has low blood sugar which is 35
# Onuralp has normal blood sugar which is 60
